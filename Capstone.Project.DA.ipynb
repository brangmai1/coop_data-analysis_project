# %%
import pandas as pd

# %%
device_loc_data = pd.read_csv(r"Device_Location.csv")

# %%
device_loc_data.head(10)
# Out:
#                                          Strategy  \
# 0  Mobile_2P_Pixel Converters_Optimized Targeting
# 1  Mobile_2P_Pixel Converters_Optimized Targeting
# 2  Mobile_2P_Pixel Converters_Optimized Targeting
# 3                                      Mobile_RON
# 4  Mobile_2P_Pixel Converters_Optimized Targeting
# 5                                      Mobile_RON
# 6  Mobile_2P_Pixel Converters_Optimized Targeting
# 7                                      Mobile_RON
# 8  Mobile_2P_Pixel Converters_Optimized Targeting
# 9                                      Mobile_RON
#
#                         DMA Name        Browser Operating System  \
# 0              Chicago, Illinois  Google Chrome     Android 10.0
# 1               Atlanta, Georgia  Google Chrome     Android 10.0
# 2              Chicago, Illinois  Google Chrome     Android 10.0
# 3              Chicago, Illinois  Google Chrome     Android 10.0
# 4              Detroit, Michigan  Google Chrome     Android 10.0
# ...

# %%
device_loc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464434 entries, 0 to 464433
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Strategy           464433 non-null  object
#  1   DMA Name           464433 non-null  object
#  2   Browser            464433 non-null  object
#  3   Operating System   464433 non-null  object
#  4   Creative Size      464433 non-null  object
#  5   Device Type        464433 non-null  object
#  6   Device Make        464433 non-null  object
#  7   Device Model       464433 non-null  object
#  8   Impressions        464433 non-null  float64
#  9   Clicks             464433 non-null  float64
#  10  Total Conversions  464433 non-null  float64
#  11  Gross Cost         464433 non-null  float64
#  12  Net Cost           464433 non-null  float64
# dtypes: float64(5), object(8)
# memory usage: 46.1+ MB

# %%
device_loc_data.describe()
# Out:
#          Impressions         Clicks  Total Conversions     Gross Cost  \
# count  464433.000000  464433.000000      464433.000000  464433.000000
# mean      153.023939       0.072351           0.002915       0.263574
# std      3474.842331       1.316353           0.146267       5.918069
# min         0.000000       0.000000           0.000000       0.000000
# 25%         1.000000       0.000000           0.000000       0.001619
# 50%         4.000000       0.000000           0.000000       0.005172
# 75%        16.000000       0.000000           0.000000       0.024769
# max    968206.000000     364.000000          32.000000    1790.812313
#
#             Net Cost
# count  464433.000000
# mean        0.084607
# std         1.899700
# min         0.000000
# 25%         0.000520
# 50%         0.001660
# 75%         0.007951
# max       574.850752

# %%
device_loc_data.shape
# Out:
# (464434, 13)

# %%
device_loc_data.dtypes
# Out:
# Strategy              object
# DMA Name              object
# Browser               object
# Operating System      object
# Creative Size         object
# Device Type           object
# Device Make           object
# Device Model          object
# Impressions          float64
# Clicks               float64
# Total Conversions    float64
# Gross Cost           float64
# Net Cost             float64
# dtype: object

# %%
device_loc_data.columns
# Out:
# Index(['Strategy', 'DMA Name', 'Browser', 'Operating System', 'Creative Size',
#        'Device Type', 'Device Make', 'Device Model', 'Impressions', 'Clicks',
#        'Total Conversions', 'Gross Cost', 'Net Cost'],
#       dtype='object')

# %%
device_loc_data.isna().sum()
# Out:
# Strategy             1
# DMA Name             1
# Browser              1
# Operating System     1
# Creative Size        1
# Device Type          1
# Device Make          1
# Device Model         1
# Impressions          1
# Clicks               1
# Total Conversions    1
# Gross Cost           1
# Net Cost             1
# dtype: int64

# %%
null_lines = device_loc_data.loc[:, 'Browser'].isna()
device_loc_data.loc[null_lines,:].head()
# Out:
# Empty DataFrame
# Columns: [Strategy, DMA Name, Browser, Operating System, Creative Size, Device Type, Device Make, Device Model, Impressions, Clicks, Total Conversions, Gross Cost, Net Cost]
# Index: []

# %%
device_loc_data = device_loc_data.fillna({
    "Strategy":"Unknown",
    "DMA Name":"Unknown",
    "Browser":"Unknown",
    "Operating System":"Unknown",
    "Creative Size":"Unknown",
    "Device Type":"Unknown",
    "Device Make":"Unknown",
    "Device Model":"Unknown",
    "Impressions":0.00,
    "Clicks":0.00,
    "Total Conversions":0.00,
    "Gross Cost":0.00,
    "Net Cost":0.00
    })

# %%
device_loc_data.isna().sum()
# Out:
# Strategy             0
# DMA Name             0
# Browser              0
# Operating System     0
# Creative Size        0
# Device Type          0
# Device Make          0
# Device Model         0
# Impressions          0
# Clicks               0
# Total Conversions    0
# Gross Cost           0
# Net Cost             0
# dtype: int64

# %%
inventory_data = pd.read_csv("dataset/Inventory.csv", encoding="windows-1254")

# %%
inventory_data.head()
# Out:
#             Brand/Company Name                       Strategy     App/URL  \
# 0  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 1  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 2  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 3  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 4  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
#
#             Exchange  Impressions  Clicks  Total Conversions  Gross Cost  \
# 0          BidSwitch          4.0     0.0                0.0    0.008026
# 1  Google Ad Manager          1.0     0.0                0.0    0.000592
# 2        Magnite DV+          7.0     0.0                0.0    0.012468
# 3              OpenX          2.0     0.0                0.0    0.005347
# 4           PubMatic          7.0     0.0                0.0    0.023199
#
#    Net Cost  Viewable Impressions  Measurable Impressions
# ...

# %%
# Check the null lines
inventory_data.size
# Out:
# 11412148

# %%
inventory_data.loc[inv_null,:]
# Out:
# Empty DataFrame
# Columns: [Brand/Company Name, Strategy , App/URL, Exchange, Impressions, Clicks, Total Conversions, Gross Cost, Net Cost, Viewable Impressions, Measurable Impressions]
# Index: []

# %%
inventory_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037468 entries, 0 to 1037467
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Brand/Company Name      1037468 non-null  object
#  1   Strategy                1037466 non-null  object
#  2   App/URL                 1037468 non-null  object
#  3   Exchange                1037468 non-null  object
#  4   Impressions             1037468 non-null  float64
#  5   Clicks                  1037468 non-null  float64
#  6   Total Conversions       1037468 non-null  float64
#  7   Gross Cost              1037468 non-null  float64
#  8   Net Cost                1037468 non-null  float64
#  9   Viewable Impressions    1037468 non-null  float64
#  10  Measurable Impressions  1037468 non-null  float64
# dtypes: float64(7), object(4)
# memory usage: 87.1+ MB

# %%
inventory_data = inventory_data.fillna({
    "Brand/Company Name":"Unknown",
    "Strategy":"Unknown",
    "App/URL":"Unknown",
    "Exchange":"Unknown",
    "Impressions":0.00,
    "Clicks":0.00,
    "Total Conversions":0.00,
    "Gross Cost":0.00,
    "Net Cost":0.00,
    "Viewable Impressions":0.00,
    "Measurable Impressions":0.00
})

# %%
inventory_data.isna().sum()
# Out:
# Brand/Company Name        0
# Strategy                  2
# App/URL                   0
# Exchange                  0
# Impressions               0
# Clicks                    0
# Total Conversions         0
# Gross Cost                0
# Net Cost                  0
# Viewable Impressions      0
# Measurable Impressions    0
# dtype: int64

# %%
audience_report_data = pd.read_csv("Audience_Report.csv")

# %%
audience_report_data.head()
# Out:
#             Brand/Company Name                    Audience Segment  \
# 0  Choose your advertiser name      Voluntary Churn Likely_60 Days
# 1  Choose your advertiser name  12 Years a Slave (2013) - Trailers
# 2  Choose your advertiser name                   14-Day Purchasers
# 3  Choose your advertiser name            170920 - NBCNews - liked
# 4  Choose your advertiser name         170920 - NBCNews - playlist
#
#   Audience List Type  Impressions  Clicks  Total Conversions  Gross Cost  \
# 0        First Party     545624.0    93.0                0.0  840.207946
# 1        First Party          1.0     0.0                0.0    0.000390
# 2        First Party        622.0     0.0                0.0    2.001355
# 3        First Party      12347.0     2.0                0.0   21.549243
# 4        First Party       5202.0    -1.0                0.0    9.127297
#
#      Net Cost
# 0  269.706751
# 1    0.000125
# 2    0.642435
# 3    6.917307
# 4    2.929862

# %%
audience_report_data.isna().sum()
# Out:
# Brand/Company Name    1
# Audience Segment      1
# Audience List Type    1
# Impressions           1
# Clicks                1
# Total Conversions     1
# Gross Cost            1
# Net Cost              1
# dtype: int64

# %%
audience_report_data = audience_report_data.fillna({
    "Brand/Company Name":"Unknown",
    "Audience Segment":"Unknown",
    "Audience List Type":"Unknown",
    "Impressions":0.00,
    "Clicks":0.00,
    "Total Conversions":0.00,
    "Gross Cost":0.00,
    "Net Cost":0.00
})

# %%
audience_report_data.isna().sum()
# Out:
# Brand/Company Name    0
# Audience Segment      0
# Audience List Type    0
# Impressions           0
# Clicks                0
# Total Conversions     0
# Gross Cost            0
# Net Cost              0
# dtype: int64

# %%
audience_report_data.shape
# Out:
# (1432, 8)

# %%
audience_report_data.to_csv(index=False)
# Out:
# 'Brand/Company Name,Audience Segment,Audience List Type,Impressions,Clicks,Total Conversions,Gross Cost,Net Cost\nChoose your advertiser name, Voluntary Churn Likely_60 Days,First Party,545624.0,93.0,0.0,840.207946,269.7067507\nChoose your advertiser name,12 Years a Slave (2013) - Trailers,First Party,1.0,0.0,0.0,0.00039,0.00012519\nChoose your advertiser name,14-Day Purchasers,First Party,622.0,0.0,0.0,2.001355,0.642434955\nChoose your advertiser name,170920 - NBCNews - liked,First Party,12347.0,2.0,0.0,21.549243,6.917307003\nChoose your advertiser name,170920 - NBCNews - playlist,First Party,5202.0,-1.0,0.0,9.127297,2.929862337\nChoose your advertiser name,170920 - NBCNews - subscribed,First Party,10984.0,4.0,0.0,20.188735,6.480583935\nChoose your advertiser name,170920 - NBCNews - viewed ad,First Party,20.0,0.0,0.0,0.105063,0.033725223\nChoose your advertiser name,170920 - NBCNews - viewed any,First Party,275835.0,129.0,0.0,485.952038,155.9906042\nChoose your advertiser name,17092
# ...

# %%
audience_report = pd.read_csv("audience_report_data.csv")

# %%
audience_report.head()
# Out:
#    Unnamed: 0           Brand/Company Name  \
# 0           0  Choose your advertiser name
# 1           1  Choose your advertiser name
# 2           2  Choose your advertiser name
# 3           3  Choose your advertiser name
# 4           4  Choose your advertiser name
#
#                      Audience Segment Audience List Type  Impressions  Clicks  \
# 0      Voluntary Churn Likely_60 Days        First Party     545624.0    93.0
# 1  12 Years a Slave (2013) - Trailers        First Party          1.0     0.0
# 2                   14-Day Purchasers        First Party        622.0     0.0
# 3            170920 - NBCNews - liked        First Party      12347.0     2.0
# 4         170920 - NBCNews - playlist        First Party       5202.0    -1.0
#
#    Total Conversions  Gross Cost    Net Cost
# 0                0.0  840.207946  269.706751
# 1                0.0    0.000390    0.000125
# 2                0.0    2.001355    0.642435
# 3                0.0   21.549243    6.917307
# ...

# %%
audience_report.isna().sum()
# Out:
# Unnamed: 0            0
# Brand/Company Name    0
# Audience Segment      0
# Audience List Type    0
# Impressions           0
# Clicks                0
# Total Conversions     0
# Gross Cost            0
# Net Cost              0
# dtype: int64

# %%
modified_inventory_data = pd.read_csv("Inventory_modified.csv", encoding="windows-1254")
modified_inventory_data.head(10)
# Out:
#             Brand/Company Name                       Strategy       App/URL  \
# 0  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 1  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 2  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 3  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 4  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 5  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 6  Choose your advertiser name  Desktop_2P_Affinity Categories    01net.com
# 7  Choose your advertiser name  Desktop_2P_Affinity Categories  0221.com.ar
# 8  Choose your advertiser name  Desktop_2P_Affinity Categories   0404.co.il
# 9  Choose your advertiser name  Desktop_2P_Affinity Categories   0begin.net
#
#                      Exchange  Impressions  Clicks  Total Conversions  \
# ...

# %%
modified_inventory_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037466 entries, 0 to 1037465
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   Brand/Company Name      1035855 non-null  object
#  1   Strategy                1035855 non-null  object
#  2   App/URL                 1035855 non-null  object
#  3   Exchange                1035855 non-null  object
#  4   Impressions             1035855 non-null  float64
#  5   Clicks                  1035855 non-null  float64
#  6   Total Conversions       1035855 non-null  float64
#  7   Gross Cost              1035855 non-null  float64
#  8   Net Cost                1035855 non-null  float64
#  9   Viewable Impressions    1035855 non-null  float64
#  10  Measurable Impressions  1035854 non-null  float64
# dtypes: float64(7), object(4)
# memory usage: 87.1+ MB

# %%
modified_inventory_data.describe()
# Out:
#         Impressions        Clicks  Total Conversions    Gross Cost  \
# count  1.035855e+06  1.035855e+06       1.035855e+06  1.035855e+06
# mean   1.843930e+02  4.211690e-02       5.118477e-03  2.692228e-01
# std    8.594999e+03  1.677090e+00       3.520554e-01  1.081934e+01
# min    0.000000e+00  0.000000e+00       0.000000e+00  0.000000e+00
# 25%    1.000000e+00  0.000000e+00       0.000000e+00  1.653000e-03
# 50%    4.000000e+00  0.000000e+00       0.000000e+00  4.766000e-03
# 75%    1.500000e+01  0.000000e+00       0.000000e+00  2.040200e-02
# max    4.154911e+06  5.820000e+02       1.540000e+02  3.807330e+03
#
#            Net Cost  Viewable Impressions  Measurable Impressions
# count  1.035855e+06          1.035855e+06            1.035854e+06
# mean   8.642052e-02          8.336962e+01            1.552381e+02
# std    3.473009e+00          4.843514e+03            7.444010e+03
# min    0.000000e+00          0.000000e+00            0.000000e+00
# ...

# %%
#modified_inventory_data.set_option('display.float_format', lambda x: '%.2f' % x)
modified_inventory_data.dtypes
# Out:
# Brand/Company Name         object
# Strategy                   object
# App/URL                    object
# Exchange                   object
# Impressions               float64
# Clicks                    float64
# Total Conversions         float64
# Gross Cost                float64
# Net Cost                  float64
# Viewable Impressions      float64
# Measurable Impressions    float64
# dtype: object

# %%
modified_inventory_data.isna().sum()
# Out:
# Brand/Company Name        1611
# Strategy                  1611
# App/URL                   1611
# Exchange                  1611
# Impressions               1611
# Clicks                    1611
# Total Conversions         1611
# Gross Cost                1611
# Net Cost                  1611
# Viewable Impressions      1611
# Measurable Impressions    1612
# dtype: int64

# %%
modified_inventory_data.isnull().sum()
# Out:
# Brand/Company Name        1611
# Strategy                  1611
# App/URL                   1611
# Exchange                  1611
# Impressions               1611
# Clicks                    1611
# Total Conversions         1611
# Gross Cost                1611
# Net Cost                  1611
# Viewable Impressions      1611
# Measurable Impressions    1612
# dtype: int64

# %%
modified_inventory_data.nunique()
# Out:
# Brand/Company Name             1
# Strategy                      12
# App/URL                    50272
# Exchange                      25
# Impressions                 7863
# Clicks                       123
# Total Conversions             44
# Gross Cost                175577
# Net Cost                  175577
# Viewable Impressions        5220
# Measurable Impressions      7178
# dtype: int64

# %%
modified_inventory_data.sort_values(by='Clicks', ascending=False).head(10)
# Out:
#                  Brand/Company Name  \
# 782816  Choose your advertiser name
# 634295  Choose your advertiser name
# 681989  Choose your advertiser name
# 979031  Choose your advertiser name
# 880333  Choose your advertiser name
# 883373  Choose your advertiser name
# 673037  Choose your advertiser name
# 664699  Choose your advertiser name
# 364492  Choose your advertiser name
# 680223  Choose your advertiser name
#
#                                               Strategy           App/URL  \
# 782816   Mobile_2P_Pixel Converters_Optimized Targeting      cbsnews.com
# 634295                 Mobile_2P_Custom Intent/Affinity      cbsnews.com
# 681989                 Mobile_2P_Custom Intent/Affinity      the-sun.com
# 979031                                       Mobile_RON  mobileposse.com
# 880333   Mobile_2P_Pixel Converters_Optimized Targeting  taboolanews.com
# 883373   Mobile_2P_Pixel Converters_Optimized Targeting      the-sun.com
# ...

# %%
modified_inventory_data.corr()
# Out:
#                         Impressions    Clicks  Total Conversions  Gross Cost  \
# Impressions                1.000000  0.500668           0.774383    0.885671
# Clicks                     0.500668  1.000000           0.387519    0.602217
# Total Conversions          0.774383  0.387519           1.000000    0.797087
# Gross Cost                 0.885671  0.602217           0.797087    1.000000
# Net Cost                   0.885671  0.602217           0.797087    1.000000
# Viewable Impressions       0.964329  0.491505           0.762009    0.847514
# Measurable Impressions     0.995894  0.510053           0.781429    0.894058
#
#                         Net Cost  Viewable Impressions  Measurable Impressions
# Impressions             0.885671              0.964329                0.995894
# Clicks                  0.602217              0.491505                0.510053
# Total Conversions       0.797087              0.762009                0.781429
# ...

# %%
modified_inventory_data.groupby('Exchange').mean()
# Out:
#                                  Impressions    Clicks  Total Conversions  \
# Exchange
# Adform                              4.206294  0.010490           0.000000
# BidSwitch                         290.568928  0.058278           0.005451
# Fluct                              12.942028  0.001970           0.000000
# Google Ad Manager                 249.118234  0.081107           0.009103
# GumGum                             14.627081  0.001907           0.000367
# Improve Digital                    14.113195  0.002074           0.000000
# InMobi                              2.454545  0.000000           0.000000
# Index Exchange                    118.479470  0.015221           0.003910
# Kargo                              41.906506  0.009159           0.000763
# Magnite DV+                       194.192397  0.031910           0.004483
# MicroAd                             1.200000  0.000000           0.000000
# ...

# %%
#modified_inventory_data[modified_inventory_data['Exchange'].str.contains('Google Ad Manager')]

# %%
modified_inventory_data.dtypes
# Out:
# Brand/Company Name         object
# Strategy                   object
# App/URL                    object
# Exchange                   object
# Impressions               float64
# Clicks                    float64
# Total Conversions         float64
# Gross Cost                float64
# Net Cost                  float64
# Viewable Impressions      float64
# Measurable Impressions    float64
# dtype: object

# %%
modified_inventory_data.select_dtypes(include='number')
# Out:
#          Impressions  Clicks  Total Conversions  Gross Cost  Net Cost  \
# 0                4.0     0.0                0.0    0.008026  0.002576
# 1                1.0     0.0                0.0    0.000592  0.000190
# 2                7.0     0.0                0.0    0.012468  0.004002
# 3                2.0     0.0                0.0    0.005347  0.001716
# 4                7.0     0.0                0.0    0.023199  0.007447
# ...              ...     ...                ...         ...       ...
# 1037461          1.0     0.0                0.0    0.000282  0.000091
# 1037462          1.0     0.0                0.0    0.002161  0.000694
# 1037463          1.0     0.0                0.0    0.001806  0.000580
# 1037464          1.0     0.0                0.0    0.000050  0.000016
# 1037465          1.0     0.0                0.0    0.000091  0.000029
#
#          Viewable Impressions  Measurable Impressions
# 0                         1.0                     4.0
# ...

# %%
modified_inventory_data.select_dtypes(include='object')
# Out:
#                   Brand/Company Name                       Strategy   \
# 0        Choose your advertiser name  Desktop_2P_Affinity Categories
# 1        Choose your advertiser name  Desktop_2P_Affinity Categories
# 2        Choose your advertiser name  Desktop_2P_Affinity Categories
# 3        Choose your advertiser name  Desktop_2P_Affinity Categories
# 4        Choose your advertiser name  Desktop_2P_Affinity Categories
# ...                              ...                             ...
# 1037461  Choose your advertiser name                      Mobile_RON
# 1037462  Choose your advertiser name                      Mobile_RON
# 1037463  Choose your advertiser name                      Mobile_RON
# 1037464  Choose your advertiser name                      Mobile_RON
# 1037465  Choose your advertiser name                      Mobile_RON
#
#               App/URL           Exchange
# 0           01net.com          BidSwitch
# 1           01net.com  Google Ad Manager
# ...

# %%
missing = modified_inventory_data.loc[:,'Clicks'].isna()
modified_inventory_data.loc[missing,:].head(20)
# Out:
#       Brand/Company Name Strategy  App/URL Exchange  Impressions  Clicks  \
# 674                  NaN       NaN     NaN      NaN          NaN     NaN
# 1095                 NaN       NaN     NaN      NaN          NaN     NaN
# 1686                 NaN       NaN     NaN      NaN          NaN     NaN
# 2042                 NaN       NaN     NaN      NaN          NaN     NaN
# 3809                 NaN       NaN     NaN      NaN          NaN     NaN
# 4141                 NaN       NaN     NaN      NaN          NaN     NaN
# 4924                 NaN       NaN     NaN      NaN          NaN     NaN
# 5108                 NaN       NaN     NaN      NaN          NaN     NaN
# 5188                 NaN       NaN     NaN      NaN          NaN     NaN
# 7312                 NaN       NaN     NaN      NaN          NaN     NaN
# 8600                 NaN       NaN     NaN      NaN          NaN     NaN
# 10405                NaN       NaN     NaN      NaN          NaN     NaN
# ...

# %%
modified_inventory_data.shape
# Out:
# (1037466, 11)

# %%
clean_inventory_data = modified_inventory_data.dropna().reset_index(drop=True)

# %%
clean_inventory_data.head()
# Out:
#             Brand/Company Name                       Strategy     App/URL  \
# 0  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 1  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 2  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 3  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
# 4  Choose your advertiser name  Desktop_2P_Affinity Categories  01net.com
#
#             Exchange  Impressions  Clicks  Total Conversions  Gross Cost  \
# 0          BidSwitch          4.0     0.0                0.0    0.008026
# 1  Google Ad Manager          1.0     0.0                0.0    0.000592
# 2        Magnite DV+          7.0     0.0                0.0    0.012468
# 3              OpenX          2.0     0.0                0.0    0.005347
# 4           PubMatic          7.0     0.0                0.0    0.023199
#
#    Net Cost  Viewable Impressions  Measurable Impressions
# ...

# %%
clean_inventory_data.isna().sum()
# Out:
# Brand/Company Name        0
# Strategy                  0
# App/URL                   0
# Exchange                  0
# Impressions               0
# Clicks                    0
# Total Conversions         0
# Gross Cost                0
# Net Cost                  0
# Viewable Impressions      0
# Measurable Impressions    0
# dtype: int64

# %%
#modified_inventory_data[modified_inventory_data['Exchange'].str.contains('Google Ad Manager')]

# %%
#clean_inventory_data = pd.DataFrame(clean_inventory_data)
url = clean_inventory_data.loc[:,'App/URL'].value_counts()
url.sort_values(ascending=False)
url.head(10)
# Out:
# dailymail.co.uk/news    197
# thestreet.com           194
# omnicalculator.com      189
# usnews.com              187
# cbsnews.com             187
# the-sun.com             186
# ranker.com              185
# investing.com           185
# screenrant.com          184
# heraldweekly.com        184
# Name: App/URL, dtype: int64

# %%
url.count()
# Out:
# 50272

# %%
# clean_inventory_data["CPC"] = []
# clean_inventory_data["CPA"] = []
# clean_inventory_data["CPM"] = []
# clean_inventory_data["CVR"] = []
# clean_inventory_data["CTR"] = []

#clean_inventory_data.info()
for items in clean_inventory_data:
    print(items[0])
    #print(clean_inventory_data[row_index][5])
    #print(clean_inventory_data[row_index][5])
    
#     for col_index in range(row_index):
#         #print(clean_inventory_data[row_index][col_index])
#         print(f"Row index {row_index}")
#         print(f"Column index {col_index}")
    if(items == 10):
        break
# Out:
# B
# S
# A
# E
# I
# C
# T
# G
# N
# V
# M
